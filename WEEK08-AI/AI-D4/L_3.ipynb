# %% [markdown]
# # L3: Retry-based Structured Output

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note <code>(Kernel Starting)</code>:</b> This notebook takes about 30 seconds to be ready to use. You may start and watch the video while you wait.</p>

# %%
import os
from utils import get_together_api_key

# %%
import instructor
from openai import OpenAI

# Instantiate the client
together_client = OpenAI(
    base_url=f"{os.getenv('DLAI_TOGETHER_API_BASE', 'https://api.together.xyz')}/v1",
    api_key=get_together_api_key()
)

# %% [markdown]
# <div style="background-color:#fff6ff; padding:13px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px">
# <p> 💻 &nbsp; <b>Access <code>requirements.txt</code> and <code>helper.py</code> files:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Open"</em>.
#
# <p> ⬇ &nbsp; <b>Download Notebooks:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Download as"</em> and select <em>"Notebook (.ipynb)"</em>.</p>
#
# <p> 📒 &nbsp; For more help, please see the <em>"Appendix – Tips, Help, and Download"</em> Lesson.</p>
# </div>

# %% [markdown]
# #### ⚠️ Compatibility Update — July 2026:
# This notebook has been updated to work with currently available models on Together AI's serverless tier.
#
# **What changed:** `meta-llama/Meta-Llama-3.1-8B-Instruct-Turbo` has been removed from Together AI's serverless tier (deprecated since March 2026). All calls to this model have been replaced with `meta-llama/Llama-3.3-70B-Instruct-Turbo`.
#
# **What to expect:** Results may differ slightly from the video, since this is a larger, more capable model (70B vs. 8B parameters) — outputs may be more detailed or phrased differently, though the structured-output and retry mechanics taught in this lesson work identically.

# %%
response = together_client.chat.completions.create(
    model='meta-llama/Llama-3.3-70B-Instruct-Turbo', # updated in 2026
    messages = [{
        "role": "user", 
        "content": 'sup'
    }]
)

response.choices[0].message.content
# Out:
# "Sup! What's up? Is there something I can help you with or would you like to chat?"

# %% [markdown]
# ## Adding Instructor

# %%
# Wrap together with the instructor client
instructor_client = instructor.from_openai(together_client)

# %%
from pydantic import BaseModel

class Greeting(BaseModel):
    hello: str

# %%
response = instructor_client.chat.completions.create(
    model='meta-llama/Llama-3.3-70B-Instruct-Turbo', # updated in 2026
    messages = [{
        "role": "user", 
        "content": 'sup'
    }], 
    # Note: OpenAI uses response_format, instructor
    #       uses response_model!
    response_model=Greeting
)

response
# Out:
# Greeting(hello='Hello')

# %% [markdown]
# ## Defining a calendar event

# %%
from pydantic import Field
from datetime import date
from typing import List

# Person only has a name, but we can easily extend it with other fields
class Person(BaseModel):
    name: str

class CalendarEvent(BaseModel):
    name: str
    
    # not supported by OpenAI. We want a format like 2025-01-30
    date: date 
    participants: List[Person]

    address_number: str
    street_name: str
    city_name: str

    # Inline regex patterns not supported by OpenAI restrict state code 
    # to be two capital letters (OpenAI does not support pattern fields)
    state_code: str = Field(pattern=r'[A-Z]{2}')

    # Zip code must be five digits
    zip_code: str = Field(pattern=r'\d{5}')

# %%
event_description = """
Alice and Bob are going to a science fair on Friday, January 2024.
The science fair is hosted at the gymnasium of Hazeldale Elementary
School at 20080 SW Farmington Road in Beaverton Oregon.
"""

# %%
def generate(
    response_model, 
    user_prompt, 
    system_prompt="You are a helpful assistant.",
    model='meta-llama/Llama-3.3-70B-Instruct-Turbo', # updated in 2026
    # Can use 70b for a higher-quality model
    max_retries=3,
):
    event = instructor_client.chat.completions.create(
        model=model,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt
            },
        ],
        response_model=response_model,
        max_retries=max_retries
    )

    return event

# %%
system_prompt = """
Make a calendar event. Respond in JSON with
the event name, date, list of participants,
and the address.
"""

user_prompt = 'Event description: ' + event_description

event = generate(
    CalendarEvent, 
    user_prompt, 
    system_prompt=system_prompt
)

# %%
event
# Out:
# CalendarEvent(name='Science Fair', date=datetime.date(2024, 1, 1), participants=[Person(name='Alice'), Person(name='Bob')], address_number='20080', street_name='SW Farmington Road', city_name='Beaverton', state_code='OR', zip_code='97005')

# %% [markdown]
# ## Retries

# %%
from utils import UsageTracker

# Clear any completion response hooks -- prevents 
# duplicate writes to the usage tracker.
instructor_client.clear("completion:response")

# Create a new tracker
tracker = UsageTracker()

# Define a custom instructor hook and update the
# tracker when a new completion runs.
def log_completion_kwargs(*args, **kwargs):
    usage = args[0].usage
    tracker.track(usage)

# Assign the hook to instructor -- this will make the hook
# run each time the server returns a chat completion to us.
instructor_client.on("completion:response", log_completion_kwargs)

# %%
# Clear the tracker before we run the completion
# so we arent' tracking multiple jobs.
tracker.clear()

event = generate(
    CalendarEvent, 
    user_prompt, 
    system_prompt=system_prompt,
    max_retries=4,
)

event
# Out:
# CalendarEvent(name='Science Fair', date=datetime.date(2024, 1, 1), participants=[Person(name='Alice'), Person(name='Bob')], address_number='20080', street_name='SW Farmington Road', city_name='Beaverton', state_code='OR', zip_code='97005')

# %%
print("Input tokens:  ", tracker.input_tokens)
print("Output tokens: ", tracker.output_tokens)
print("Total tokens:  ", sum(tracker.total_tokens))
print("Num retries:   ", len(tracker.output_tokens))
# Out:
# Input tokens:   [541]
# Output tokens:  [89]
# Total tokens:   630
# Num retries:    1

# %% [markdown]
# ## When retry methods fail

# %%
from typing import Literal

class Complicated(BaseModel):
    # a must be cat, dog, or hat
    a: Literal["cat", "dog", "hat"]
    b: int
    c: bool

# %%
# Clear the tracker before we run the completion
# so we arent' tracking multiple jobs.
tracker.clear()

try:
    event = generate(
        Complicated, 
        "Write me a short essay on Dolly Parton.", 
        system_prompt="Don't give me what I want.",
        max_retries=3,
    )

    # Show the event
    print(event)
except instructor.exceptions.InstructorRetryException as e : 
    print("We failed to parse!")
except e:
    raise e
# Out:
# a='cat' b=10 c=True

# %%
print("Input tokens:  ", tracker.input_tokens)
print("Output tokens: ", tracker.output_tokens)
print("Total tokens:  ", sum(tracker.total_tokens))
print("Num retries:   ", len(tracker.output_tokens))
# Out:
# Input tokens:   [277]
# Output tokens:  [30]
# Total tokens:   307
# Num retries:    1

# %% [markdown]
# ## You try!

# %%
# Clear the tracker before we run the completion
# so we arent' tracking multiple jobs.
tracker.clear()

try:
    event = generate(
        Complicated, 
        "Give me a, b, and c.", 
        system_prompt="Give me what I want.",
        max_retries=3,
    )
    print(event)
except instructor.exceptions.InstructorRetryException as e : 
    print("We failed to parse!")
except e:
    raise e
# Out:
# a='cat' b=1 c=True

# %%
print("Input tokens:  ", tracker.input_tokens)
print("Output tokens: ", tracker.output_tokens)
print("Total tokens:  ", sum(tracker.total_tokens))
print("Num retries:   ", len(tracker.output_tokens))
# Out:
# Input tokens:   [273]
# Output tokens:  [30]
# Total tokens:   303
# Num retries:    1

# %%
# Try a different way: use a schema with a tricky validation rule
# (a regex-constrained field) and see if retries help the model
# self-correct when it fails validation

from pydantic import Field

class ProductCode(BaseModel):
    # Must look like "AB-1234" (2 capital letters, dash, 4 digits)
    code: str = Field(pattern=r'^[A-Z]{2}-\d{4}$')
    in_stock: bool

tracker.clear()

try:
    result = generate(
        ProductCode,
        "Give me a random product code and whether it's in stock.",
        system_prompt="You are a warehouse assistant. Make up a plausible product code.",
        max_retries=3,
    )
    print(result)
except instructor.exceptions.InstructorRetryException as e:
    print("We failed to parse!")

print("Input tokens:  ", tracker.input_tokens)
print("Output tokens: ", tracker.output_tokens)
print("Total tokens:  ", sum(tracker.total_tokens))
print("Num retries:   ", len(tracker.output_tokens))
# Out:
# code='AB-1234' in_stock=True
# Input tokens:   [260]
# Output tokens:  [28]
# Total tokens:   288
# Num retries:    1

# %%
# Compare low vs high max_retries on the same hard prompt,
# to see how retry budget affects whether it succeeds

for retries in [1, 3]:
    tracker.clear()
    print(f"--- max_retries = {retries} ---")
    try:
        result = generate(
            Complicated,
            "Write me a short essay on Dolly Parton.",
            system_prompt="Don't give me what I want.",
            max_retries=retries,
        )
        print(result)
    except instructor.exceptions.InstructorRetryException:
        print("We failed to parse!")
    print("Num retries used:", len(tracker.output_tokens))
    print("Total tokens:    ", sum(tracker.total_tokens))
    print()
# Out:
# --- max_retries = 1 ---
# a='cat' b=10 c=True
# Num retries used: 1
# Total tokens:     307
#
# --- max_retries = 3 ---
# a='cat' b=1 c=False
# Num retries used: 1
# Total tokens:     306
