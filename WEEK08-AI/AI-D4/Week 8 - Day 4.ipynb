# %% [markdown]
# # Introduction to Structured Outputs

# %% [markdown]
# Please Complete the following course in the lab today:
#
# https://learn.deeplearning.ai/courses/getting-structured-llm-output/lesson/cat89/introduction
# - Take your time experimenting with the structures ->
# - Try producing json objects relevant to a project you're trying to implement, using your prompts and techniques mentioned in the course. For example generating a json object of analysis of a patient's mental health condition based on their answers to phsychological questions.
#  ```
# {
#   "total_score": 16,
#   "severity": "Moderate Anxiety",
#   "interpretation": "The patient's score indicates moderate anxiety. Further evaluation and possible treatment are recommended.",
#   "recommendations": [
#     "Referral to a mental health specialist for further evaluation",
#     "Cognitive Behavioral Therapy (CBT) sessions",
#     "Regular follow-up appointments to monitor progress",
#     "Lifestyle changes including exercise and stress management techniques"
#   ],
#   "notes": "The patient has reported increased stress levels at work and difficulty sleeping. These factors may be contributing to the anxiety symptoms."
# }
#  ```
# <br><br>
# - For submission, download the notebooks and screenshot of completion of the course. Make sure notebooks include your attempts of trying different prompting strategies.
#
#
# Notes:
#
# While Deeplearning.ai offers sandbox for code execution and api key for Generative AI courses, they tend to face service outages often. Try to complete the code execution in one go, without taking any breaks
# The course mentions it's one hour but that only includes video time, so use your time effectively for both the lectures and excercises.

# %% [markdown]
# # Brainstorming activity

# %% [markdown]
# - Start researching and brainstorming usecases for your final project and discuss with the instructor in this lab or the coming labs.
# - It is preferred to keep this as an individual project, unless it is absolutely necessary for students to work in groups on specialised areas of an effective usecase.
